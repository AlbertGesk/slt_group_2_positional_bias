# %%
from slt_positional_bias.dataset import generate_merged_data_frame, sort_data_frame, store_df_as_parquet, load_parquet_as_df, normalize_and_tokenize, jaccard

df_name = "output_cleaned_df"
df = load_parquet_as_df(df_name)
# Out:
# 2025-08-09 16:47:27.100 | INFO     | slt_positional_bias.config:<module>:11 - PROJ_ROOT path is: C:\Users\Albert\Documents\SLT\slt_group_2_positional_bias
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Albert\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#          topic_id                                        doc_id  rel_scoring  \
# 0     2024-127266  msmarco_v2.1_doc_51_1637162254#13_3136723187            0
# 1     2024-127266    msmarco_v2.1_doc_08_564630335#9_1002896073            0
# 2     2024-127266   msmarco_v2.1_doc_19_1124745018#2_1589311387            0
# 3     2024-127266    msmarco_v2.1_doc_54_361376333#16_839575849            0
# 4     2024-127266    msmarco_v2.1_doc_51_877973062#2_1847163672            0
# ...           ...                                           ...          ...
# 1595   2024-96063   msmarco_v2.1_doc_25_947435380#15_1757291433            0
# 1596   2024-96063   msmarco_v2.1_doc_52_1260126505#8_2526623662            3
# 1597   2024-96063   msmarco_v2.1_doc_33_1002533346#9_2137815825            3
# 1598   2024-96063   msmarco_v2.1_doc_14_1335772831#2_2728776902            3
# 1599   2024-96063   msmarco_v2.1_doc_52_1260126505#7_2526620166            3
#
#                                                   topic  \
# 0     what are some key challenges related to the re...
# 1     what are some key challenges related to the re...
# 2     what are some key challenges related to the re...
# 3     what are some key challenges related to the re...
# 4     what are some key challenges related to the re...
# ...                                                 ...
# 1595            how using maps can impact your pedagogy
# 1596            how using maps can impact your pedagogy
# 1597            how using maps can impact your pedagogy
# 1598            how using maps can impact your pedagogy
# 1599            how using maps can impact your pedagogy
#
#                                                     doc
# 0     solid waste management (swg) is a major challe...
# 1     importance of recycling plastic  \ntypes of pl...
# 2     recycling for sustainability. the benefits of ...
# 3     e-waste recycling facts and figures  \nsustain...
# 4     in 2012, illinois epa passed the electronics p...
# ...                                                 ...
# 1595  intersectional pedagogy emphasizes analyzing h...
# 1596  maps and map learning play a critical role in ...
# 1597  mind mapping enhances pedagogy by improving st...
# 1598  8 visual teaching strategies to win over your ...
# 1599  maps and map learning in social studies involv...
#
# [1600 rows x 5 columns]
