# %% [markdown]
# ### Join tests
#
# Core Idea:
# 1. Only relevance scoring linked to an existing query are needed,
# 2. Only pairs of `(relevance score, query)` to which a corpus is linked are needed.
# 3. Remove all entries where `qid = NaN`
#
#
# This results in the following two join operations:
# - ( (relevance-scoring [topic_id] ⟖ queries [qid]) [doc_id]) ⟖ corpus [docno]

# %%
import json
import pandas as pd
import sys
from pathlib import Path
from IPython.display import display

from slt_positional_bias.dataset import generate_data_frame

corpus_df = generate_data_frame("data/interim/inputs/corpus.jsonl")
queries_df = generate_data_frame("data/interim/inputs/queries.jsonl")
relevance_df = generate_data_frame("data/interim/inputs/qrels.rag24.test-umbrela-all.txt")

relevance_df.columns = ["topic_id", "q0", "doc_id", "scoring"]
corpus_df
# Out:
# 2025-07-03 12:18:18.589 | INFO     | slt_positional_bias.dataset:generate_data_frame:20 - file path exists
# 2025-07-03 12:18:29.631 | INFO     | slt_positional_bias.dataset:generate_data_frame:20 - file path exists
# 2025-07-03 12:18:29.639 | INFO     | slt_positional_bias.dataset:generate_data_frame:20 - file path exists
#                                                docno  \
# 0        msmarco_v2.1_doc_52_1400719578#0_2842698387
# 1        msmarco_v2.1_doc_05_1495231781#3_2850145650
# 2        msmarco_v2.1_doc_12_1016316941#1_1992316811
# 3        msmarco_v2.1_doc_34_1545449353#0_3251041439
# 4       msmarco_v2.1_doc_23_1497031463#10_3313663249
# ...                                              ...
# 116689     msmarco_v2.1_doc_56_94836053#11_205606001
# 116690    msmarco_v2.1_doc_44_596645538#4_1407144514
# 116691  msmarco_v2.1_doc_49_1086472702#22_2229413969
# 116692   msmarco_v2.1_doc_34_1540555152#9_3240635353
# 116693  msmarco_v2.1_doc_53_1119612308#16_2492012852
#
#                                                      text  \
# 0       Taylor Swift's "Invisible String" Lyrics Meani...
# 1       History of Ancient Rome for Kids: The Roman Em...
# 2       Apiphobia and Spheksophobia - Fear Of Wasps An...
# 3       Reies Tijerina | American activist | Britannic...
# 4       Salome: Was the "dancing" daughter of Herodias...
# ...                                                   ...
# 116689  TSHA | DeWitt's Colony DeWitt's Colony\nSuppor...
# 116690  SAFE Investment Company (China) Definition SAF...
# 116691  Money is Everything - Physician on FIRE Money ...
# 116692  Maximilien Robespierre | Biography, French Rev...
# 116693  eCommDirect - inmate Commissary Purchases and ...
#
#                                         original_document
# 0       {'doc_id': 'msmarco_v2.1_doc_52_1400719578#0_2...
# 1       {'doc_id': 'msmarco_v2.1_doc_05_1495231781#3_2...
# 2       {'doc_id': 'msmarco_v2.1_doc_12_1016316941#1_1...
# 3       {'doc_id': 'msmarco_v2.1_doc_34_1545449353#0_3...
# 4       {'doc_id': 'msmarco_v2.1_doc_23_1497031463#10_...
# ...                                                   ...
# 116689  {'doc_id': 'msmarco_v2.1_doc_56_94836053#11_20...
# 116690  {'doc_id': 'msmarco_v2.1_doc_44_596645538#4_14...
# 116691  {'doc_id': 'msmarco_v2.1_doc_49_1086472702#22_...
# 116692  {'doc_id': 'msmarco_v2.1_doc_34_1540555152#9_3...
# 116693  {'doc_id': 'msmarco_v2.1_doc_53_1119612308#16_...
#
# [116694 rows x 3 columns]

# %%
queries_df
# Out:
#             qid                                              query  \
# 0   2024-145979  what is vicarious trauma and how can it be cop...
# 1   2024-216592     why disability insurance is a smart investment
# 2    2024-32912  how bad did the vietnam war devastate the econ...
# 3   2024-153051       what target stors's policies for shoplifting
# 4   2024-128784    what can a career in civil engineering be like?
# ..          ...                                                ...
# 84  2024-219563          why free things have less percieved value
# 85  2024-121840  should teachers notify parents about state tes...
# 86   2024-58819  how many latino have been misinformed about ed...
# 87   2024-42014            how does religion show in public school
# 88  2024-127266  what are some key challenges related to the re...
#
#                                        original_query
# 0   {'query_id': '2024-145979', 'text': 'what is v...
# 1   {'query_id': '2024-216592', 'text': 'why disab...
# 2   {'query_id': '2024-32912', 'text': 'how bad di...
# 3   {'query_id': '2024-153051', 'text': 'what targ...
# 4   {'query_id': '2024-128784', 'text': 'what can ...
# ..                                                ...
# 84  {'query_id': '2024-219563', 'text': 'why free ...
# 85  {'query_id': '2024-121840', 'text': 'should te...
# 86  {'query_id': '2024-58819', 'text': 'how many l...
# 87  {'query_id': '2024-42014', 'text': 'how does r...
# 88  {'query_id': '2024-127266', 'text': 'what are ...
#
# [89 rows x 3 columns]

# %%
relevance_df
# Out:
#            topic_id  q0                                       doc_id  scoring
# 0       2024-145979  Q0    msmarco_v2.1_doc_01_523681915#0_449763684        2
# 1       2024-145979  Q0  msmarco_v2.1_doc_13_1647729865#0_3617397938        3
# 2       2024-145979  Q0  msmarco_v2.1_doc_25_1148700328#0_2179512504        2
# 3       2024-145979  Q0  msmarco_v2.1_doc_25_1148700328#1_2179514079        2
# 4       2024-145979  Q0  msmarco_v2.1_doc_44_1043805224#2_2182641075        2
# ...             ...  ..                                          ...      ...
# 108473   2024-21669  Q0    msmarco_v2.1_doc_08_298503251#1_568833050        0
# 108474   2024-21669  Q0   msmarco_v2.1_doc_27_877180220#2_1765802089        1
# 108475   2024-21669  Q0  msmarco_v2.1_doc_01_1752638978#7_2584141250        1
# 108476   2024-21669  Q0  msmarco_v2.1_doc_09_914336366#11_1554208777        0
# 108477   2024-21669  Q0  msmarco_v2.1_doc_26_812182301#10_1581123427        0
#
# [108478 rows x 4 columns]

# %%
queries_df["qid"].is_unique
# Out:
# True

# %%
relevance_queries_merged_df = relevance_df.merge(queries_df, how="right", left_on="topic_id", right_on="qid")
corpus_df["docno"].is_unique
# Out:
# True

# %%
relevance_queries_corpus_merged = relevance_queries_merged_df.merge(corpus_df, how="right", left_on="doc_id", right_on="docno")
relevance_queries_corpus_merged["qid"].isna().any()
# Out:
# np.True_

# %%
unified_df = relevance_queries_corpus_merged[relevance_queries_corpus_merged["qid"].notna()]
unified_df
# Out:
#            topic_id  q0                                       doc_id  scoring  \
# 3        2024-36302  Q0  msmarco_v2.1_doc_34_1545449353#0_3251041439      0.0
# 8       2024-224279  Q0  msmarco_v2.1_doc_53_1158657184#4_2578103489      3.0
# 13       2024-41918  Q0    msmarco_v2.1_doc_25_386750115#1_757017149      1.0
# 14       2024-43983  Q0   msmarco_v2.1_doc_47_847662737#3_1828675438      0.0
# 18      2024-158677  Q0    msmarco_v2.1_doc_17_535302055#4_580294086      1.0
# ...             ...  ..                                          ...      ...
# 116789   2024-96359  Q0   msmarco_v2.1_doc_02_897225352#7_1560248853      1.0
# 116798   2024-42497  Q0   msmarco_v2.1_doc_55_291506052#15_666138048      2.0
# 116800   2024-29182  Q0  msmarco_v2.1_doc_38_1238509282#5_2504074815      1.0
# 116802   2024-35284  Q0   msmarco_v2.1_doc_33_579672422#1_1236816866      0.0
# 116803   2024-36302  Q0    msmarco_v2.1_doc_56_94836053#11_205606001      0.0
#
#                 qid                                              query  \
# 3        2024-36302    how did old riaño residents protest relocation?
# 8       2024-224279  why should teachers always be reviewing their ...
# 13       2024-41918     how does plutonium help us improve technology?
# 14       2024-43983  how has inclusivity made vogue magazine more p...
# 18      2024-158677  what was entertainment like in the 1990s in th...
# ...             ...                                                ...
# 116789   2024-96359  how were the non aligned countries affected by...
# 116798   2024-42497  how does the informal recycling sector add to ...
# 116800   2024-29182     does your mood have an effect on buying things
# 116802   2024-35284     how did andrew carnegie impact modern medicine
# 116803   2024-36302    how did old riaño residents protest relocation?
#
#                                            original_query  \
# 3       {'query_id': '2024-36302', 'text': 'how did ol...
# 8       {'query_id': '2024-224279', 'text': 'why shoul...
# 13      {'query_id': '2024-41918', 'text': 'how does p...
# 14      {'query_id': '2024-43983', 'text': 'how has in...
# 18      {'query_id': '2024-158677', 'text': 'what was ...
# ...                                                   ...
# 116789  {'query_id': '2024-96359', 'text': 'how were t...
# 116798  {'query_id': '2024-42497', 'text': 'how does t...
# 116800  {'query_id': '2024-29182', 'text': 'does your ...
# 116802  {'query_id': '2024-35284', 'text': 'how did an...
# 116803  {'query_id': '2024-36302', 'text': 'how did ol...
#
#                                               docno  \
# 3       msmarco_v2.1_doc_34_1545449353#0_3251041439
# 8       msmarco_v2.1_doc_53_1158657184#4_2578103489
# 13        msmarco_v2.1_doc_25_386750115#1_757017149
# 14       msmarco_v2.1_doc_47_847662737#3_1828675438
# 18        msmarco_v2.1_doc_17_535302055#4_580294086
# ...                                             ...
# 116789   msmarco_v2.1_doc_02_897225352#7_1560248853
# 116798   msmarco_v2.1_doc_55_291506052#15_666138048
# 116800  msmarco_v2.1_doc_38_1238509282#5_2504074815
# 116802   msmarco_v2.1_doc_33_579672422#1_1236816866
# 116803    msmarco_v2.1_doc_56_94836053#11_205606001
#
#                                                      text  \
# 3       Reies Tijerina | American activist | Britannic...
# 8       4 Benefits of Monitoring Student Progress in t...
# 13      What Is Plutonium? Characteristics of This Nuc...
# 14      Despite Featuring Plus-Size Models, Victoria’s...
# 18      Entertainment technology - Wikipedia Entertain...
# ...                                                   ...
# 116789  Boris Yeltsin's Legacy BORIS YELTSIN'S FOREIGN...
# 116798  Essay on Air Pollution: 9 Selected Essays on A...
# 116800  Top 6 Reasons to Buy Her Flowers, and What Eve...
# 116802  Paracelsus — Toxipedia \n He felt that sicknes...
# 116803  TSHA | DeWitt's Colony DeWitt's Colony\nSuppor...
#
#                                         original_document
# 3       {'doc_id': 'msmarco_v2.1_doc_34_1545449353#0_3...
# 8       {'doc_id': 'msmarco_v2.1_doc_53_1158657184#4_2...
# 13      {'doc_id': 'msmarco_v2.1_doc_25_386750115#1_75...
# 14      {'doc_id': 'msmarco_v2.1_doc_47_847662737#3_18...
# 18      {'doc_id': 'msmarco_v2.1_doc_17_535302055#4_58...
# ...                                                   ...
# 116789  {'doc_id': 'msmarco_v2.1_doc_02_897225352#7_15...
# 116798  {'doc_id': 'msmarco_v2.1_doc_55_291506052#15_6...
# 116800  {'doc_id': 'msmarco_v2.1_doc_38_1238509282#5_2...
# 116802  {'doc_id': 'msmarco_v2.1_doc_33_579672422#1_12...
# 116803  {'doc_id': 'msmarco_v2.1_doc_56_94836053#11_20...
#
# [29163 rows x 10 columns]
