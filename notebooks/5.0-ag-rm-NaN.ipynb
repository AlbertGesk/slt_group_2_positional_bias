# %%
from slt_positional_bias.dataset import generate_data_frame, generate_merged_data_frame

df = generate_merged_data_frame()
df
# Out:
# 2025-07-22 20:18:51.880 | INFO     | slt_positional_bias.config:<module>:11 - PROJ_ROOT path is: C:\Users\Albert\Documents\SLT\slt_group_2_positional_bias
# 2025-07-22 20:18:52.677 | INFO     | slt_positional_bias.dataset:generate_data_frame:55 - file path exists
# 2025-07-22 20:18:57.544 | INFO     | slt_positional_bias.dataset:generate_data_frame:55 - file path exists
# 2025-07-22 20:18:57.549 | INFO     | slt_positional_bias.dataset:generate_data_frame:55 - file path exists
# 2025-07-22 20:18:57.768 | INFO     | slt_positional_bias.dataset:generate_merged_data_frame:41 - df column 'doc_id' is unique: True
# 2025-07-22 20:18:57.776 | INFO     | slt_positional_bias.dataset:generate_merged_data_frame:42 - df contains NaN: False
#           topic_id                                       doc_id  rel_scoring  \
# 0      2024-145979    msmarco_v2.1_doc_01_523681915#0_449763684            2
# 1      2024-145979  msmarco_v2.1_doc_13_1647729865#0_3617397938            3
# 2      2024-145979  msmarco_v2.1_doc_25_1148700328#0_2179512504            2
# 3      2024-145979  msmarco_v2.1_doc_25_1148700328#1_2179514079            2
# 4      2024-145979  msmarco_v2.1_doc_44_1043805224#2_2182641075            2
# ...            ...                                          ...          ...
# 29158  2024-127266  msmarco_v2.1_doc_58_1230815815#5_1795053441            2
# 29159  2024-127266   msmarco_v2.1_doc_34_470264225#3_1018882699            0
# 29160  2024-127266   msmarco_v2.1_doc_57_781229369#6_1221950031            1
# 29161  2024-127266   msmarco_v2.1_doc_57_781235684#6_1221962946            1
# 29162  2024-127266   msmarco_v2.1_doc_04_996421513#0_2067362452            0
#
#                                                    topic  \
# 0      what is vicarious trauma and how can it be cop...
# 1      what is vicarious trauma and how can it be cop...
# 2      what is vicarious trauma and how can it be cop...
# 3      what is vicarious trauma and how can it be cop...
# 4      what is vicarious trauma and how can it be cop...
# ...                                                  ...
# 29158  what are some key challenges related to the re...
# 29159  what are some key challenges related to the re...
# 29160  what are some key challenges related to the re...
# 29161  what are some key challenges related to the re...
# 29162  what are some key challenges related to the re...
#
#                                                      doc
# 0      Vicarious traumatization - Wikipedia Vicarious...
# 1      Vicarious Trauma: What Causes it and Ways to H...
# 2      What is Vicarious Trauma? | What is Vicarious ...
# 3      What is Vicarious Trauma? | What is Vicarious ...
# 4      What is Vicarious Trauma? - Jefferson Center -...
# ...                                                  ...
# 29158  Highest E-Waste Generating Nations In The Worl...
# 29159  The Pros & Cons Of Landfills (Benefits & Disad...
# 29160  The Patron Saint of Electronics? Do you Know t...
# 29161  Destroy VHS Tapes \nDestroy VHS Tapes\nDaliah ...
# 29162  How Does Recycling Affect The Environment? Pos...
#
# [28951 rows x 5 columns]
